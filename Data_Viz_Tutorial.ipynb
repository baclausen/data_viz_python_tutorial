# %% [markdown]
# # Data Visualization in Python
# Take data and turn it into something colorful, graphical and meaningful :)

# %% [markdown]
# ## Intro
# Data visualization allows data scientists to graphically represent data to extract and understand trends, outliers, patterns and further insights in the data.
#
# Python has many **many** graphing libraries with different features and it can be daunting to know which library to use.  This intro tutorial will focus on a few popular plotting libraries:
# * **Pandas** - built on Matplotlib and easy to use with Pandas dataframes
# * **Matplotlib** - massive library with lots of flexibility (stackoverflow will be your friend!)
# * **Seaborn** - statistical visualization with default themes and beautiful styles
#
# For interactive plots and possibly a feature tutorial
# * Plotly
# * D3
# * Bokeh
#
#
# This tutorial compares Matplotlib, Pandas and Seaborn for the following visualizations:
# * Scatter Plots
# * Line Charts
# * Histograms
# * Bar Charts
# * Box Plots
# * Pie Charts
# * Heatmaps
# * Faceting
# * Pairplots

# %% [markdown]
# ### Setup
# Personally, I prefer to use a Conda environment and/or Docker container (if you are interested in knowing more about these setups let me know).  The README includes the specific packages you will need for this tutorial.  Please make sure you can run the following line without any errors.

# %%
## Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_wine, load_iris

# %matplotlib inline

# %% [markdown]
# ### Note:
# You may have to install or update the library `jinja2` for certain highlighting
# options to work (depending on the bug correction schedules for the `jinja2` or
# `pandas` development teams).

# %% [markdown]
# ## Data
# Scikit-learn includes out of the box [datasets](https://scikit-learn.org/stable/datasets/index.html#]) which are great for practicing your data visualization skills.  We will use the classic wine and iris datasets - imported above.
#
# Since most of the plotting libraries play very nicely with Pandas DataFrames, we will format the *wine* and *iris* dataset with Pandas.

# %%
# Load the wine data set into a Pandas dataframe and view the first 5 rows
wine = load_wine()
wine_df = pd.DataFrame(data= np.c_[wine.data, wine.target],
                 columns= list(wine.feature_names) + ['target'])
# Add class label
wine_df['class'] = pd.Categorical.from_codes(wine.target, wine.target_names)

# Show the top 5 rows of Dataframe
wine_df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target    class
# 0                          3.92   1065.0     0.0  class_0
# 1                          3.40   1050.0     0.0  class_0
# 2                          3.17   1185.0     0.0  class_0
# 3                          3.45   1480.0     0.0  class_0
# 4                          2.93    735.0     0.0  class_0

# %%
# Load the iris data set into a Pandas dataframe and view the first 5 rows
iris = load_iris()
iris_df =  pd.DataFrame(data= np.c_[iris.data, iris.target],
                 columns= list(iris.feature_names) + ['target'])

# Add class label
iris_df['class'] = pd.Categorical.from_codes(iris.target, iris.target_names)

# Show the top 5 rows of Dataframe
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target   class
# 0     0.0  setosa
# 1     0.0  setosa
# 2     0.0  setosa
# 3     0.0  setosa
# 4     0.0  setosa

# %% [markdown]
# ### Pandas DataFrame Descriptive Statistics
# Don't forget to understand the statistics of your data!  You can also stylize your dataframe like you might in a csv.  There are ways to add visual impact to quantitative data.
#
# If you need a brief statistical refresher especially in the context of Python please see [Python Statistics Fundamentals: How to Describe Your Data](https://realpython.com/python-statistics/).

# %%
# Generate descriptive statistics of your DataFrame
wine_df.describe()
# wine_df.describe(include="all")
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# min         0.980000    0.340000              0.130000         0.410000
# 25%         1.742500    1.205000              0.270000         1.250000
# 50%         2.355000    2.135000              0.340000         1.555000
# 75%         2.800000    2.875000              0.437500         1.950000
# max         3.880000    5.080000              0.660000         3.580000
#
#        color_intensity         hue  od280/od315_of_diluted_wines      proline  \
# count       178.000000  178.000000                    178.000000   178.000000
# mean          5.058090    0.957449                      2.611685   746.893258
# std           2.318286    0.228572                      0.709990   314.907474
# min           1.280000    0.480000                      1.270000   278.000000
# 25%           3.220000    0.782500                      1.937500   500.500000
# 50%           4.690000    0.965000                      2.780000   673.500000
# 75%           6.200000    1.120000                      3.170000   985.000000
# max          13.000000    1.710000                      4.000000  1680.000000
#
#            target
# count  178.000000
# mean     0.938202
# std      0.775035
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000

# %%
# Generate descriptive statistics of your DataFrame
iris_df.describe()
# iris_df.describe(include="all")
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
# Example using a color gradient to display data values in the DataFrame
# For max/min use highlight_max()/highlight_min()
display_wine_df = (wine_df.style
          .background_gradient(cmap='coolwarm', subset=wine_df.select_dtypes('number').columns)
          .highlight_max(color='green', subset=wine_df.select_dtypes('number').columns)
          .highlight_min(color='gray', subset=wine_df.select_dtypes('number').columns))

display_wine_df

# styled_wine_df variable creates an object for a formatted view of our df, and does not change the data in our dataframe
# Out:
# <style type="text/css">
# #T_04bbc_row0_col0, #T_04bbc_row104_col11 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T
col10 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   background-color: gray;
# }
# #T_04bbc_row1_col1, #T_04bbc_row6_col3, #T_04bbc_row12_col4, #T_04bbc_row26_col1, #T_04bbc_row38_col9, #T_04bbc_row44_col1, #T_04bbc_row77_col6, #T_04bbc_row96_col0, #T_04bbc_row119_col12, #T_04bbc_row123_col10, #T_04bbc_row135_col10, #T_04bbc_row136_col4, #T_04bbc_row141_col4, #T_04bbc_row156_col4, #T_04bbc_row158_col6, #T_04bbc_row159_col4, #T_04bbc_row170_col11, #T_04bbc_row173_col8 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_04bbc_row1_col2, #T_04bbc_row27_col2, #T_04bbc_row74_col10, #T_04bbc_row78_col7 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_04bbc_row1_col3, #T_04bbc_row84_col1, #T_04bbc_row136_col6, #T_04bbc_row138_col6, #T_04bbc_row165_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_04bbc_row1_col4, #T_04bbc_row4_col12, #T_04bbc_row19_col9, #T_04bbc_row26_col8, #T_04bbc_row35_col4, #T_04bbc_row35_col9, #T_04bbc_row37_col8, #T_04bbc_row39_col9, #T_04bbc_row42_col10, #T_04bbc_row44_col10, #T_04bbc_row61_col4, #T_04bbc_row107_col10, #T_04bbc_row113_col8, #T_04bbc_row120_col1, #T_04bbc_row148_col5, #T_04bbc_row171_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_04bbc_row1_col5, #T_04bbc_row29_col5, #T_04bbc_row30_col10, #T_04bbc_row45_col2, #T_04bbc_row57_col11, #T_04bbc_row65_col10, #T_04bbc_row76_col10, #T_04bbc_row79_col10, #T_04bbc_row126_col11, #T_04bbc_row150_col4 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_04bbc_row1_col6, #T_04bbc_row12_col6, #T_04bbc_row17_col7, #T_04bbc_row32_col12, #T_04bbc_row35_col3, #T_04bbc_row40_col2, #T_04bbc_row40_col4, #T_04bbc_row44_col8, #T_04bbc_row55_col3, #T_04bbc_row56_col8, #T_04bbc_row82_col7, #T_04bbc_row86_col2, #T_04bbc_row87_col7, #T_04bbc_row104_col3, #T_04bbc_row115_col5, #T_04bbc_row128_col7, #T_04bbc_row146_col7, #T_04bbc_row163_col0, #T_04bbc_row163_col7, #T_04bbc_row167_col7, #T_04bbc_row170_col7, #T_04bbc_row173_col3 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_04bbc_row1_col7, #T_04bbc_row11_col7, #T_04bbc_row23_col7, #T_04bbc_row29_col7, #T_04bbc_row35_col7, #T_04bbc_row56_col7, #T_04bbc_row57_col1, #T_04bbc_row66_col7, #T_04bbc_row74_col0, #T_04bbc_row81_col7, #T_04bbc_row90_col6, #T_04bbc_row100_col7, #T_04bbc_row110_col2, #T_04bbc_row111_col7, #T_04bbc_row133_col10, #T_04bbc_row152_col7, #T_04bbc_row159_col12, #T_04bbc_row165_col10 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_04bbc_row1_col8, #T_04bbc_row21_co

# %%
iris_df.loc[:, 'sepal length (cm)': 'petal width (cm)'].head(10).style.background_gradient(subset=['sepal length (cm)', 'petal length (cm)'], cmap='BuGn').background_gradient(subset=['sepal width (cm)', 'petal width (cm)'], cmap='PuRd').highlight_max(color='yellow')
# Out:
# <style type="text/css">
# #T_cdf04_row0_col0 {
#   background-color: #2f9858;
#   color: #f1f1f1;
# }
# #T_cdf04_row0_col1 {
#   background-color: #e53592;
#   color: #f1f1f1;
# }
# #T_cdf04_row0_col2, #T_cdf04_row1_col2, #T_cdf04_row4_col2, #T_cdf04_row6_col2, #T_cdf04_row8_col2 {
#   background-color: #cdece6;
#   color: #000000;
# }
# #T_cdf04_row0_col3, #T_cdf04_row1_col3, #T_cdf04_row2_col3, #T_cdf04_row3_col3, #T_cdf04_row4_col3, #T_cdf04_row7_col3, #T_cdf04_row8_col3 {
#   background-color: #cda0cd;
#   color: #000000;
# }
# #T_cdf04_row1_col0, #T_cdf04_row3_col2, #T_cdf04_row7_col2, #T_cdf04_row9_col0, #T_cdf04_row9_col2 {
#   background-color: #65c2a3;
#   color: #000000;
# }
# #T_cdf04_row1_col1 {
#   background-color: #eae5f1;
#   color: #000000;
# }
# #T_cdf04_row2_col0 {
#   background-color: #b8e4db;
#   color: #000000;
# }
# #T_cdf04_row2_col1 {
#   background-color: #d0abd3;
#   color: #000000;
# }
# #T_cdf04_row2_col2, #T_cdf04_row8_col0 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_cdf04_row3_col0, #T_cdf04_row6_col0 {
#   background-color: #d6f0ee;
#   color: #000000;
# }
# #T_cdf04_row3_col1, #T_cdf04_row9_col1 {
#   background-color: #dcc9e2;
#   color: #000000;
# }
# #T_cdf04_row4_col0, #T_cdf04_row7_col0 {
#   background-color: #48b27f;
#   color: #f1f1f1;
# }
# #T_cdf04_row4_col1 {
#   background-color: #d81b6a;
#   color: #f1f1f1;
# }
# #T_cdf04_row5_col0, #T_cdf04_row5_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   background-color: yellow;
# }
# #T_cdf04_row5_col1, #T_cdf04_row5_col3 {
#   background-color: #67001f;
#   color: #f1f1f1;
#   background-color: yellow;
# }
# #T_cdf04_row6_col1, #T_cdf04_row7_col1 {
#   background-color: #df64af;
#   color: #f1f1f1;
# }
# #T_cdf04_row6_col3 {
#   background-color: #df2179;
#   color: #f1f1f1;
# }
# #T_cdf04_row8_col1, #T_cdf04_row9_col3 {
#   background-color: #f7f4f9;
#   color: #000000;
# }
# </style>
# <table id="T_cdf04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cdf04_level0_col0" class="col_heading level0 col0" >sepal length (cm)</th>
#       <th id="T_cdf04_level0_col1" class="col_heading level0 col1" >sepal width (cm)</th>
#       <th id="T_cdf04_level0_col2" class="col_heading level0 col2" >petal length (cm)</th>
#       <th id="T_cdf04_level0_col3" class="col_heading level0 col3" >petal width (cm)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdf04_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cdf04_row0_col0" class="data row0 col0" >5.100000</td>
#       <td id="T_cdf04_row0_col1" class="data row0 col1" >3.500000</td>
#       <td id="T_cdf04_row0_col2" class="data row0 col2" >1.400000</td>
#       <td id="T_cdf04_row0_col3" class="data row0 col3" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_cdf04_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cdf04_row1_col0" class="data row1 col0" >4.900000</td>
#       <td id="T_cdf04_row1_col1" class="data row1 col1" >3.000000</td>
#       <td id="T_cdf04_row1_col2" class="data row1 col2" >1.400000</td>
#       <td id="T_cdf04_row1_col3" class="data row1 col3" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_cdf04_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cdf04_row2_col0" class="data row2 col0" >4.700000</td>
#       <td id="T_cdf04_row2_col1" class="data row2 col1" >3.200000</td>
#       <td id="T_cdf04_row2_col2" class="data row2 col2" >1.300000</td>
#       <td id="T_cdf04_row2_col3" class="data row2 col3" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_cdf04_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cdf04_row3_col0" class="data row3 col0" >4.600000</td>
#       <td id="T_cdf04_row3_col1" class="data row3 col1" >3.100000</td>
#       <td id="T_cdf04_row3_col2" class="data row3 col2" >1.500000</td>
#       <td id="T_cdf04_row3_col3" class="data row3 col3" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_cdf04_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cdf04_row4_col0" class="data row4 col0" >5.000000</td>
#       <td id="T_cdf04_row4_col1" class="data row4 col1" >3.600000</td>
#       <td id="T_cdf04_row4_col2" class="data row4 col2" >1.400000</td>
#       <td id="T_cdf04_row4_col3" class="data row4 col3" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_cdf04_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cdf04_row5_col0" class="data row5 col0" >5.400000</td>
#       <td id="T_cdf04_row5_col1" class="data row5 col1" >3.900000</td>
#       <td id="T_cdf04_row5_col2" class="data row5 col2" >1.700000</td>
#       <td id="T_cdf04_row5_col3" class="data row5 col3" >0.400000</td>
#     </tr>
#     <tr>
#       <th id="T_cdf04_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cdf04_row6_col0" class="data row6 col0" >4.600000</td>
#       <td id="T_cdf04_row6_col1" class="data row6 col1" >3.400000</td>
#       <td id="T_cdf04_row6_col2" class="data row6 col2" >1.400000</td>
#       <td id="T_cdf04_row6_col3" class="data row6 col3" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_cdf04_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cdf04_row7_col0" class="data row7 col0" >5.000000</td>
#       <td id="T_cdf04_row7_col1" class="data row7 col1" >3.400000</td>
#       <td id="T_cdf04_row7_col2" class="data row7 col2" >1.500000</td>
#       <td id="T_cdf04_row7_col3" class="data row7 col3" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_cdf04_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cdf04_row8_col0" class="data row8 col0" >4.400000</td>
#       <td id="T_cdf04_row8_col1" class="data row8 col1" >2.900000</td>
#       <td id="T_cdf04_row8_col2" class="data row8 col2" >1.400000</td>
#       <td id="T_cdf04_row8_col3" class="data row8 col3" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_cdf04_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cdf04_row9_col0" class="data row9 col0" >4.900000</td>
#       <td id="T_cdf04_row9_col1" class="data row9 col1" >3.100000</td>
#       <td id="T_cdf04_row9_col2" class="data row9 col2" >1.500000</td>
#       <td id="T_cdf04_row9_col3" class="data row9 col3" >0.100000</td>
#     </tr>
#   </tbody>
# </table>

# %%
display_iris_df = (iris_df.style
          .background_gradient(cmap='coolwarm', subset=iris_df.select_dtypes('number').columns)
          .highlight_max(color='green', subset=iris_df.select_dtypes('number').columns)
          .highlight_min(color='gray', subset=iris_df.select_dtypes('number').columns))

display_iris_df
# Out:
# <style type="text/css">
# #T_885b2_row0_col0, #T_885b2_row17_col0, #T_885b2_row19_col0, #T_885b2_row21_col0, #T_885b2_row23_col0, #T_885b2_row39_col0, #T_885b2_row44_col0, #T_885b2_row46_col0, #T_885b2_row98_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_885b2_row0_col1, #T_885b2_row17_col1, #T_885b2_row27_col1, #T_885b2_row36_col1, #T_885b2_row40_col1, #T_885b2_row43_col1 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_885b2_row0_col2, #T_885b2_row1_col2, #T_885b2_row4_col2, #T_885b2_row6_col2, #T_885b2_row8_col2, #T_885b2_row12_col2, #T_885b2_row17_col2, #T_885b2_row28_col2, #T_885b2_row33_col2, #T_885b2_row37_col2, #T_885b2_row45_col2, #T_885b2_row47_col2, #T_885b2_row49_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_885b2_row0_col3, #T_885b2_row1_col3, #T_885b2_row2_col3, #T_885b2_row3_col3, #T_885b2_row4_col3, #T_885b2_row7_col3, #T_885b2_row8_col3, #T_885b2_row10_col3, #T_885b2_row11_col3, #T_885b2_row14_col3, #T_885b2_row20_col3, #T_885b2_row22_col3, #T_885b2_row24_col3, #T_885b2_row25_col3, #T_885b2_row27_col3, #T_885b2_row28_col3, #T_885b2_row29_col3, #T_885b2_row30_col3, #T_885b2_row33_col3, #T_885b2_row34_col3, #T_885b2_row35_col3, #T_885b2_row36_col3, #T_885b2_row38_col3, #T_885b2_row39_col3, #T_885b2_row42_col3, #T_885b2_row46_col3, #T_885b2_row47_col3, #T_885b2_row48_col3, #T_885b2_row49_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_885b2_row0_col4, #T_885b2_row1_col4, #T_885b2_row2_col4, #T_885b2_row3_col4, #T_885b2_row4_col4, #T_885b2_row5_col4, #T_885b2_row6_col4, #T_885b2_row7_col4, #T_885b2_row8_col4, #T_885b2_row9_col3, #T_885b2_row9_col4, #T_885b2_row10_col4, #T_885b2_row11_col4, #T_885b2_row12_col3, #T_885b2_row12_col4, #T_885b2_row13_col0, #T_885b2_row13_col3, #T_885b2_row13_col4, #T_885b2_row14_col4, #T_885b2_row15_col4, #T_885b2_row16_col4, #T_885b2_row17_col4, #T_885b2_row18_col4, #T_885b2_row19_col4, #T_885b2_row20_col4, #T_885b2_row21_col4, #T_885b2_row22_col2, #T_885b2_row22_col4, #T_885b2_row23_col4, #T_885b2_row24_col4, #T_885b2_row25_col4, #T_885b2_row26_col4, #T_885b2_row27_col4, #T_885b2_row28_col4, #T_885b2_row29_col4, #T_885b2_row30_col4, #T_885b2_row31_col4, #T_885b2_row32_col3, #T_885b2_row32_col4, #T_885b2_row33_col4, #T_885b2_row34_col4, #T_885b2_row35_col4, #T_885b2_row36_col4, #T_885b2_row37_col3, #T_885b2_row37_col4, #T_885b2_row38_col4, #T_885b2_row39_col4, #T_885b2_row40_col4, #T_885b2_row41_col4, #T_885b2_row42_col4, #T_885b2_row43_col4, #T_885b2_row44_col4, #T_885b2_row45_col4, #T_885b2_row46_col4, #T_885b2_row47_col4, #T_885b2_row48_col4, #T_885b2_row49_col4, #T_885b2_row60_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#
col1 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_885b2_row2_col2, #T_885b2_row16_col2, #T_885b2_row36_col2, #T_885b2_row38_col2, #T_885b2_row40_col2, #T_885b2_row41_col2, #T_885b2_row42_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_885b2_row3_col0, #T_885b2_row3_col2, #T_885b2_row6_col0, #T_885b2_row6_col3, #T_885b2_row7_col2, #T_885b2_row9_col2, #T_885b2_row10_col2, #T_885b2_row15_col2, #T_885b2_row17_col3, #T_885b2_row18_col3, #T_885b2_row19_col2, #T_885b2_row19_col3, #T_885b2_row21_col2, #T_885b2_row22_col0, #T_885b2_row27_col2, #T_885b2_row31_col2, #T_885b2_row32_col2, #T_885b2_row34_col2, #T_885b2_row39_col2, #T_885b2_row40_col3, #T_885b2_row41_col3, #T_885b2_row45_col3, #T_885b2_row47_col0, #T_885b2_row48_col2, #T_885b2_row62_col1, #T_885b2_row68_col1, #T_885b2_row119_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_885b2_row3_col1, #T_885b2_row9_col1, #T_885b2_row30_col1, #T_885b2_row34_col1, #T_885b2_row52_col1, #T_885b2_row65_col1, #T_885b2_row73_col3, #T_885b2_row81_col2, #T_885b2_row82_col3, #T_885b2_row86_col1, #T_885b2_row90_col3, #T_885b2_row92_col3, #T_885b2_row95_col3, #T_885b2_row137_col1, #T_885b2_row139_col1, #T_885b2_row140_col1, #T_885b2_row141_col1 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_885b2_row4_col0, #T_885b2_row7_col0, #T_885b2_row25_col0, #T_885b2_row26_col0, #T_885b2_row35_col0, #T_885b2_row40_col0, #T_885b2_row43_col0, #T_885b2_row49_col0, #T_885b2_row60_col0, #T_885b2_row93_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_885b2_row4_col1, #T_885b2_row22_col1, #T_885b2_row37_col1, #T_885b2_row65_col0, #T_885b2_row77_col0, #T_885b2_row77_col3, #T_885b2_row86_col0, #T_885b2_row106_col3, #T_885b2_row108_col0, #T_885b2_row109_col1, #T_885b2_row124_col0, #T_885b2_row140_col0, #T_885b2_row144_col0, #T_885b2_row145_col0 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_885b2_row5_col0, #T_885b2_row10_col0, #T_885b2_row16_col0, #T_885b2_row20_col0, #T_885b2_row31_col0, #T_885b2_row84_col0 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_885b2_row5_col1, #T_885b2_row16_col1, #T_885b2_row110_col3, #T_885b2_row113_col3, #T_885b2_row121_col3, #T_885b2_row122_col3, #T_885b2_row131_col3, #T_885b2_row147_col3 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_885b2_row5_col2, #T_885b2_row18_col2, #T_885b2_row20_col2, #T_885b2_row23_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_885b2_row5_col3, #T_885b2_row15_col3, #T_885b2_row16_col3, #T_885b2_row21_col3, #T_885b2_row26_col3, #T_885b2_row31_col3, #T_885b2_

# %%
# Example using a color gradient to display data values in the DataFrame
# For max/min use highlight_max()/highlight_min()

# %% [markdown]
# # Scatter Plots
# The x-y plot or scatter plot represents the pairs of data from two datasets.

# %% [markdown]
# ### Matplotlib
# Use **scatter** or use **plt.subplots** to stylize our plot with title and labels.

# %%
# create a figure and axis
fig, ax = plt.subplots()

# scatter the sepal_length against the sepal_width
ax.scatter(iris_df['sepal length (cm)'], iris_df['sepal width (cm)'])

# set a title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal length (cm)')
ax.set_ylabel('sepal width (cm)')
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %% [markdown]
# The plot would have more meaning if the data points are colored by class.  In Matplotlib we can create a color dictionary and then assign a color for each class.

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target   class
# 0     0.0  setosa
# 1     0.0  setosa
# 2     0.0  setosa
# 3     0.0  setosa
# 4     0.0  setosa

# %%
# create color dictionary
colors = {'setosa':'r', 'versicolor':'g', 'virginica':'b'}
# create a figure and axis
fig, ax = plt.subplots()
# plot each data-point
for c in np.unique(iris_df['class']):
    ax.scatter(iris_df['sepal length (cm)'].loc[iris_df['class']==c], 
               iris_df['sepal width (cm)'].loc[iris_df['class']==c],
               s=10*iris_df['petal length (cm)'].loc[iris_df['class']==c],
               alpha=0.5,
               color=colors[c],
               label = c)

# set a title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal length (cm)')
ax.set_ylabel('sepal width (cm)')
ax.legend(loc='best')

# %% [markdown]
# ### Pandas
# To create a scatter plot in Pandas we can call **dataset.plot.scatter()**. The axes labels will automatically be created from the DataFrame column names.

# %%
# create Pandas scatter plot
iris_df.plot.scatter(x='sepal length (cm)', y='sepal width (cm)', title='Iris Dataset')
# Out:
# <Axes: title={'center': 'Iris Dataset'}, xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %%
iris_df.head(1)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
#
#    target   class
# 0     0.0  setosa

# %%
# Add coloring to plot by class 
# Note here we use the numeric target and not the class names
iris_df.plot.scatter(x='sepal length (cm)', 
                     y='sepal width (cm)', 
                     title='Iris Dataset', 
                     c='target',
                     colormap='viridis')
# Out:
# <Axes: title={'center': 'Iris Dataset'}, xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %% [markdown]
# ### Seaborn
# Seaborn has a **.scatterplot** method to create a scatterplot similar to Pandas.

# %%
# create a seaborn scatter plot

plt.title('Iris Dataset')
# Out:
# Text(0.5, 1.0, 'Iris Dataset')

# %%
# add style to scatterplot by coloring by class
sns.scatterplot(x='sepal length (cm)', 
                y='sepal width (cm)',
                data=iris_df,
                hue = 'class',
                size='petal length (cm)')
plt.title('Iris Dataset')
plt.legend(loc='upper center', bbox_to_anchor=(1.3, 1.0),
          fancybox=True, shadow=True, ncol=1)
plt.tight_layout()

# %% [markdown]
# # Line Chart
# One of the most fundamental plots - a line chart to display a series of data points.

# %% [markdown]
# ### Matplotlib
# Call line-chart with the method **plot**.  Matplotlib will require a loop to plot multiple columns in one graph.

# %%
# get columns to plot
columns = iris_df.columns.drop(['target', 'class'])
# create x data
x = iris_df.index

# create figure and axis
fig, ax = plt.subplots()
# plot each column

for col in columns:
    ax.plot(x, iris_df[col], label=col)

# set title and legend
ax.set_title('Iris Dataset')
ax.set_xlabel('Sample')
ax.set_ylabel('Measurement (cm)')
ax.legend()

# %% [markdown]
# ## Pandas
# Create line-chart with **.plot.line()** without any loops :)

# %%
# pandas line chart

ax = iris_df.drop(['target', 'class'], axis=1).plot.line()
ax.set_title('Iris Dataset')
ax.set_xlabel('Sample')
ax.set_ylabel('Measurement (cm)')
# Out:
# Text(0, 0.5, 'Measurement (cm)')

# %% [markdown]
# ### Seaborn
# Line-chart with seaborn calls method sns.lineplot

# %%
# seaborn line chart 

ax = sns.lineplot(iris_df.drop('target', axis=1))

ax.set_title('Iris Dataset')
ax.set_xlabel('Sample')
ax.set_ylabel('Measurement (cm)')
# Out:
# Text(0, 0.5, 'Measurement (cm)')

# %% [markdown]
# # Histograms
# Histograms are useful for a large number of unique values in a dataset.  The values are sorted into intervals, called bins.  From histograms we can understand the distribution (aka frequency) of the data.

# %% [markdown]
# ### Matplotlib
# Use method **hist**.

# %%
wine_df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target    class
# 0                          3.92   1065.0     0.0  class_0
# 1                          3.40   1050.0     0.0  class_0
# 2                          3.17   1185.0     0.0  class_0
# 3                          3.45   1480.0     0.0  class_0
# 4                          2.93    735.0     0.0  class_0

# %%
# create figure and axis
fig, ax = plt.subplots()
# plot histogram
plt.hist(wine_df['alcohol'], bins=10)

# set title and labels
ax.set_title('Wine Alcohol')
ax.set_xlabel('Alcohol')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Pandas
# Create Pandas hist with **plot.hist** - no parameters required.

# %%
# histogram using Pandas
wine_df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Also easily create mulitple plots 
iris_df.drop(['target', 'class'], axis=1).plot.hist(subplots=True, layout=(2,2), figsize=(10, 10), bins=20)
# Out:
# array([[<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#        [<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>]],
#       dtype=object)

# %% [markdown]
# ### Seaborn
# Seaborn uses method **sns.distplot** with many additional parameters.

# %%
# sns histogram
sns.histplot(wine_df['alcohol'], bins=8)
plt.ylabel('Frequency')
plt.title('Wine Alcohol')
# Out:
# Text(0.5, 1.0, 'Wine Alcohol')

# %%
# sns histogram with kernel density estimate
sns.histplot(wine_df['alcohol'], bins=8, kde=True)
plt.ylabel('Frequency')
plt.title('Wine Alcohol')
plt.ylabel('Distribution')
plt.title('Wine Alcohol')
# Out:
# Text(0.5, 1.0, 'Wine Alcohol')

# %% [markdown]
# # Bar Charts
# Bar charts illustrate data corresponding to given labels or discrete numeric values (like pies charts).  These charts are good when there is low cardinality (not a lot of categories)

# %% [markdown]
# ### Matplotlib
# Use the **bar** method, with the caveat that you need to manually calculate the frequencies of the categories you are interested in which can be done using **value_counts**.

# %%
# create a figure and axis 
fig, ax = plt.subplots() 
# count the occurrence of each class 
data = wine_df['class'].value_counts() 
# get x and y data 
alcohol = data.index 
frequency = data.values 
# create bar chart 
ax.bar(alcohol, frequency)
# set title and labels 
ax.set_title('Wine Classes') 
ax.set_xlabel('Class') 
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Pandas
# Use **plot.bar()** method, but like with matplotlib this method requires that we need to count the occurrences using **value_counts** and sort using **sort_index**.

# %%
wine_df['class'].value_counts().sort_index().plot.barh(color=['red', 'blue', 'green'])
plt.title('Wine Classes')
plt.ylabel('Class')
plt.xlabel('Count')
# Out:
# Text(0.5, 0, 'Count')

# %%
avg_alcohol = wine_df.groupby('class')['alcohol'].mean().sort_index()
avg_alcohol.plot.bar('class', 'alcohol')

plt.title('Wine Classes with the Highest Alcohol (on Average)')
plt.xlabel('Class')
plt.ylabel('Average Alcohol')
# Out:
# C:\Users\burto\AppData\Local\Temp\ipykernel_18536\3313369294.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_alcohol = wine_df.groupby('class')['alcohol'].mean().sort_index()
# Text(0, 0.5, 'Average Alcohol')

# %% [markdown]
# ### Seaborn
# Use **.countplot** to create a bar-chart, no need to do any data manipulation :)

# %%
sns.countplot(wine_df['class'], palette='viridis')
plt.title('Wine Class')
# Out:
# C:\Users\burto\AppData\Local\Temp\ipykernel_18536\2241106030.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(wine_df['class'], palette='viridis')
# Text(0.5, 1.0, 'Wine Class')

# %% [markdown]
# # Box Plots
# Box plots (and violin plots) are excellent for visualizing descriptive statistics of a dataset since they show the range, interquartile range, median, mode, outliers and all quartiles.

# %% [markdown]
# ### Matplotlib
# Use the method **boxplot()**.  In order to display multiple columns in one figure we need to construct an array of data.

# %%
# get columns to plot
columns = iris_df.columns.drop(['target', 'class'])
data = []
for column in columns:
    data.append(iris_df[column])
# create figure and axis
fig, ax = plt.subplots()
# plot each column
ax.boxplot(data, labels=columns)

# set title and legend
ax.set_title('Iris Dataset')
ax.set_xticklabels(columns, rotation=45)
ax.set_xlabel('Feature')
ax.set_ylabel('cm')
# Out:
# C:\Users\burto\AppData\Local\Temp\ipykernel_18536\2171989635.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(data, labels=columns)
# Text(0, 0.5, 'cm')

# %% [markdown]
# ### Pandas
# Use **.boxplot()** to create boxplot from Pandas dataframe.

# %%
iris_df.boxplot()
plt.xticks(rotation=15)
plt.title('Iris Dataset')
plt.xlabel('Feature')
plt.ylabel('cm')
# Out:
# Text(0, 0.5, 'cm')

# %% [markdown]
# ### Seaborn
# Just need **sns.boxplot()** method to create amazing boxplots

# %%
sns.boxplot(iris_df.drop(['target'], axis=1))
plt.title('Iris Dataset')
plt.xlabel('Feature')
plt.ylabel('cm')
plt.xticks(rotation=20)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'sepal length (cm)'),
#   Text(1, 0, 'sepal width (cm)'),
#   Text(2, 0, 'petal length (cm)'),
#   Text(3, 0, 'petal width (cm)')])

# %%
sns.boxplot(iris_df.drop(['target'], axis=1))
# Out:
# <Axes: >

# %%
# Boxplots are also useful for viewing the different statistics of a feature broken down by class
fig, ax = plt.subplots(2, 2)

sns.boxplot(iris_df.drop(['target'], axis=1), x='class', y='sepal length (cm)', ax=ax[0, 0])
sns.boxplot(iris_df.drop(['target'], axis=1), x='class', y='sepal width (cm)', ax=ax[0,1])
sns.boxplot(iris_df.drop(['target'], axis=1), x='class', y='petal length (cm)', ax=ax[1,0])
sns.boxplot(iris_df.drop(['target'], axis=1), x='class', y='petal width (cm)', ax=ax[1,1])

plt.tight_layout()

# %%
# Alternative to box plot is a violin plot showing 
# the kernel density estimation underlying the distribution
sns.violinplot(x="class", y="sepal length (cm)", data=iris_df)
plt.title('Iris Dataset')
# Out:
# Text(0.5, 1.0, 'Iris Dataset')

# %% [markdown]
# # Pie Charts
# Represent data with a small number of labels and given relative frequencies.

# %% [markdown]
# ### Matplotlib
# Use **plt.pie** method to create a pie chart.

# %%
#first create data arrays 
data = wine_df['class'].value_counts()
labels = data.index.tolist()
sizes = data.values
colors = ['yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0)  # explode 1st slice

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%')

plt.tight_layout()
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Pandas
# Use the method **.plot.pie** on a dataframe.

# %%
wine_df['class'].value_counts().plot.pie(autopct='%1.2f%%', shadow=True)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Seaborn
# Sorry but seaborn does not have a piechart method :(

# %% [markdown]
# # Heatmaps
# Heatmaps can visually represent a matrix.  The colors represent the numbers or elements of the matrix.  They are used for showing covariance and correlation matrices. Pandas **.corr()** allows you to easily create a correlation matrix or you can use numpy **np.corrcoef** method.

# %% [markdown]
# ### Matplotlib
# Use Pandas correlation **.corr()** to easily get the correlation of features inside a dataframe and results in a correlation matrix.

# %%
# get correlation matrix
corr = iris_df.corr(numeric_only=True)
fig, ax = plt.subplots()

# create heatmap
#sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
ax.imshow(corr)

# set labels
ax.set_xticks(np.arange(len(corr.columns)))
ax.set_yticks(np.arange(len(corr.columns)))
ax.set_xticklabels(corr.columns)
ax.set_yticklabels(corr.columns)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        text = ax.text(j, i, np.around(corr.iloc[i, j], decimals=2),
                       ha="center", va="center", color="black")

# %% [markdown]
# ### Pandas
# Although Pandas lets you quickly calculate the correlation matrix, you will need Matplotlib or Seaborn to plot the heatmap.

# %% [markdown]
# ### Seaborn
# The best and easiest way to create a heatmap!!

# %%
# Add a mask so you don't show redundant information

# %% [markdown]
# # Faceting
# Faceting allows you to break the data variables up across multiple subplots and
# combine into a single feature.  This will allow you to quickly explore and
# visualize your datasets. Faceting is most easily accomplished in Seaborn.

# %% [markdown]
# ### Seaborn
# Faceting in Seaborn uses a FacetGrid,  You first define the **FacetGrid** and pass the data and column which you want to use to split your data.   Then use the **map** function on the FacetGrid object to make the multiple subplots with the different slices of data.

# %%
# Create FacetGrid

# use map function with a histogram

# %% [markdown]
# # Pairwise Data Compairson
# Pandas and Seaborn both have methods to plot pairwise relationships in your dataset - which can be extremely useful - just be careful for large datasets.

# %% [markdown]
# ### Pandas
# Pandas has a **scatter_matrix** which makes it easy to

# %%
fig, ax = plt.subplots(figsize=(12,12))
# img = pd.plotting.scatter_matrix()

# %% [markdown]
# ### Seaborn
# Seaborn also has a very useful **pairplot** method that automatically plots a grid of pairwise relationships in the dataset.
